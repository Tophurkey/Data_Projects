# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
url = "https://api.covid19api.com/summary"

response = requests.request("GET", url)

#print(response.text)

# %%
#Parse request response with json.loads()
#Parse json file with json.load()

json_r = response.json()

json_r
# Out:
# {'ID': '122db93b-83c3-41b9-abef-06b099e051de',
#  'Message': '',
#  'Global': {'NewConfirmed': 417435,
#   'TotalConfirmed': 197101200,
#   'NewDeaths': 4355,
#   'TotalDeaths': 4205917,
#   'NewRecovered': 91018,
#   'TotalRecovered': 129372326,
#   'Date': '2021-07-31T16:59:39.33Z'},
#  'Countries': [{'ID': '1d3a2d4d-faf1-45d3-a03f-e0b5e02205c1',
#    'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 146523,
#    'NewDeaths': 0,
#    'TotalDeaths': 6677,
#    'NewRecovered': 0,
#    'TotalRecovered': 82586,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '77a93968-f09b-4780-99d7-6d8081d22271',
#    'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 133036,
#    'NewDeaths': 0,
#    'TotalDeaths': 2457,
#    'NewRecovered': 0,
#    'TotalRecovered': 130205,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'bace0953-5c29-4361-8705-4ff3dba239b9',
#    'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 170189,
#    'NewDeaths': 0,
#    'TotalDeaths': 4219,
#    'NewRecovered': 0,
#    'TotalRecovered': 114531,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e1270727-cb8d-4a11-82c7-db32fa567a31',
#    'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14678,
#    'NewDeaths': 0,
#    'TotalDeaths': 128,
#    'NewRecovered': 0,
#    'TotalRecovered': 14210,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'b8cba5a9-03b3-41f6-917f-9b19c68ae1dc',
#    'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 42646,
#    'NewDeaths': 0,
#    'TotalDeaths': 1008,
#    'NewRecovered': 0,
#    'TotalRecovered': 36708,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '6d0aa475-62a9-4282-bc9f-48649226fbd5',
#    'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1303,
#    'NewDeaths': 0,
#    'TotalDeaths': 43,
#    'NewRecovered': 0,
#    'TotalRecovered': 1235,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '3ae0fbeb-2ad3-43e3-98ca-ea290f59a442',
#    'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4919408,
#    'NewDeaths': 0,
#    'TotalDeaths': 105586,
#    'NewRecovered': 0,
#    'TotalRecovered': 4557037,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '41f3e20d-8022-4699-8819-e18a0a922a23',
#    'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 229867,
#    'NewDeaths': 0,
#    'TotalDeaths': 4608,
#    'NewRecovered': 0,
#    'TotalRecovered': 219701,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'cdeb44ed-da94-4f73-9d9b-04dee2e01f03',
#    'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 221,
#    'TotalConfirmed': 34130,
#    'NewDeaths': 1,
#    'TotalDeaths': 924,
#    'NewRecovered': 23,
#    'TotalRecovered': 24059,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f6068c2b-396a-4d86-8516-83954265b160',
#    'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 658518,
#    'NewDeaths': 0,
#    'TotalDeaths': 10737,
#    'NewRecovered': 0,
#    'TotalRecovered': 642597,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'db25a9e2-4533-477d-a7af-1dbf19b170b6',
#    'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 343216,
#    'NewDeaths': 0,
#    'TotalDeaths': 5022,
#    'NewRecovered': 0,
#    'TotalRecovered': 332752,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '37f9802a-1f25-49e0-9769-7f4de22c53be',
#    'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14677,
#    'NewDeaths': 0,
#    'TotalDeaths': 286,
#    'NewRecovered': 0,
#    'TotalRecovered': 12570,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1a7eb232-a527-43fd-88c5-2fc854f81787',
#    'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 269080,
#    'NewDeaths': 0,
#    'TotalDeaths': 1384,
#    'NewRecovered': 0,
#    'TotalRecovered': 266705,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'eeede255-5be2-42ca-9d85-0377c56e307a',
#    'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1240115,
#    'NewDeaths': 0,
#    'TotalDeaths': 20467,
#    'NewRecovered': 0,
#    'TotalRecovered': 1064195,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '82ef5536-f324-452c-b76e-04997a257ec5',
#    'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4379,
#    'NewDeaths': 0,
#    'TotalDeaths': 48,
#    'NewRecovered': 0,
#    'TotalRecovered': 4198,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '8a483912-d149-473d-9c0d-935fe2e835f9',
#    'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 445048,
#    'NewDeaths': 0,
#    'TotalDeaths': 3445,
#    'NewRecovered': 0,
#    'TotalRecovered': 439162,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5e8cf475-6b22-467b-85d3-1940a04544e2',
#    'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 1764,
#    'TotalConfirmed': 1124715,
#    'NewDeaths': 6,
#    'TotalDeaths': 25241,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a4016d6e-8800-4cc3-ad8d-39b0a07e1717',
#    'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14163,
#    'NewDeaths': 0,
#    'TotalDeaths': 337,
#    'NewRecovered': 0,
#    'TotalRecovered': 13420,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '502bd8c7-a169-4a71-8874-1b85ec5be764',
#    'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8394,
#    'NewDeaths': 0,
#    'TotalDeaths': 108,
#    'NewRecovered': 0,
#    'TotalRecovered': 8136,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1ce379be-4892-4fc0-800a-4c85526cee60',
#    'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2508,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 2371,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ef640986-1341-46da-a046-96e2a9ad2cbc',
#    'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 471958,
#    'NewDeaths': 0,
#    'TotalDeaths': 17784,
#    'NewRecovered': 0,
#    'TotalRecovered': 405853,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'd2ac7144-e220-46f3-96c0-7d3b9c9be6b1',
#    'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 205655,
#    'NewDeaths': 0,
#    'TotalDeaths': 9687,
#    'NewRecovered': 0,
#    'TotalRecovered': 189369,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1aa256b5-7c6c-4362-87f5-6dc2b3a2153e',
#    'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 106690,
#    'NewDeaths': 0,
#    'TotalDeaths': 1569,
#    'NewRecovered': 0,
#    'TotalRecovered': 95323,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '8ee144f7-6927-408f-9fc6-9ea7fdde2630',
#    'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 40904,
#    'TotalConfirmed': 19880273,
#    'NewDeaths': 963,
#    'TotalDeaths': 555460,
#    'NewRecovered': 0,
#    'TotalRecovered': 17771228,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '34c3958d-3bff-491f-86a2-88d25c25bc7c',
#    'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 336,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 278,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f9b7cf99-91e1-4a89-b812-26b59851d25b',
#    'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 424872,
#    'NewDeaths': 0,
#    'TotalDeaths': 18211,
#    'NewRecovered': 0,
#    'TotalRecovered': 398536,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '85e5589d-98b0-4aa0-9b5b-18e8843cfc0c',
#    'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13573,
#    'NewDeaths': 0,
#    'TotalDeaths': 169,
#    'NewRecovered': 0,
#    'TotalRecovered': 13369,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '371911d2-735a-43a3-986e-da05a868636c',
#    'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7080,
#    'NewDeaths': 0,
#    'TotalDeaths': 9,
#    'NewRecovered': 0,
#    'TotalRecovered': 773,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f17011a0-e4d5-45db-93b0-ca3c98953b8e',
#    'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 76585,
#    'NewDeaths': 0,
#    'TotalDeaths': 1375,
#    'NewRecovered': 0,
#    'TotalRecovered': 69198,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'd2be3a2d-9b16-40ae-b7bd-ecb7b12564f1',
#    'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 82064,
#    'NewDeaths': 0,
#    'TotalDeaths': 1334,
#    'NewRecovered': 0,
#    'TotalRecovered': 35261,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'fa2ec886-3c27-4c50-a317-40896fe55f73',
#    'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 723,
#    'TotalConfirmed': 1203700,
#    'NewDeaths': 6,
#    'TotalDeaths': 24224,
#    'NewRecovered': 332,
#    'TotalRecovered': 1403960,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1edbacd6-df60-4930-a966-79a5a8b597cf',
#    'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 33763,
#    'NewDeaths': 0,
#    'TotalDeaths': 298,
#    'NewRecovered': 0,
#    'TotalRecovered': 32976,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '66468194-fc1b-42c7-8dca-7a8f74eeb629',
#    'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7151,
#    'NewDeaths': 0,
#    'TotalDeaths': 98,
#    'NewRecovered': 0,
#    'TotalRecovered': 6859,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a20a1f32-72a9-491c-bfa8-118974d74d72',
#    'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4973,
#    'NewDeaths': 0,
#    'TotalDeaths': 174,
#    'NewRecovered': 0,
#    'TotalRecovered': 4792,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '581d75e6-48c1-46e7-bf21-745e4180df34',
#    'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 1341,
#    'TotalConfirmed': 1614629,
#    'NewDeaths': 71,
#    'TotalDeaths': 35366,
#    'NewRecovered': 687,
#    'TotalRecovered': 1568981,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a9f37c5d-d304-4fff-96ec-6762b1973a0c',
#    'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 55,
#    'TotalConfirmed': 104973,
#    'NewDeaths': 0,
#    'TotalDeaths': 4848,
#    'NewRecovered': 28,
#    'TotalRecovered': 99091,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '540306cc-8d65-4c8a-9ca0-7a0d5778bbb1',
#    'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 9462,
#    'TotalConfirmed': 4776291,
#    'NewDeaths': 306,
#    'TotalDeaths': 120432,
#    'NewRecovered': 9872,
#    'TotalRecovered': 4567701,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '39aea3f4-0a91-4f57-9e8e-52da6f14bf9d',
#    'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4026,
#    'NewDeaths': 0,
#    'TotalDeaths': 147,
#    'NewRecovered': 0,
#    'TotalRecovered': 3864,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0111791f-0a06-496a-9cec-0e87bb76c014',
#    'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13186,
#    'NewDeaths': 0,
#    'TotalDeaths': 178,
#    'NewRecovered': 0,
#    'TotalRecovered': 12421,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '859f26b4-83d9-483d-bb00-c2212fae0c41',
#    'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 49562,
#    'NewDeaths': 0,
#    'TotalDeaths': 1023,
#    'NewRecovered': 0,
#    'TotalRecovered': 29497,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'dedf1d38-45a0-4fef-8432-eaa6c92a8fd8',
#    'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 406814,
#    'NewDeaths': 0,
#    'TotalDeaths': 5030,
#    'NewRecovered': 0,
#    'TotalRecovered': 329639,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '20acdb1e-e025-46d8-8400-322aa750b961',
#    'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 363397,
#    'NewDeaths': 0,
#    'TotalDeaths': 8254,
#    'NewRecovered': 0,
#    'TotalRecovered': 354055,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '8a06038f-117f-42af-90c4-fa2f12e5970e',
#    'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 375721,
#    'NewDeaths': 0,
#    'TotalDeaths': 2693,
#    'NewRecovered': 0,
#    'TotalRecovered': 329811,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a02ccf5c-18db-4f17-80e6-f295577e6f15',
#    'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 101419,
#    'NewDeaths': 0,
#    'TotalDeaths': 419,
#    'NewRecovered': 0,
#    'TotalRecovered': 39061,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '79ead881-0a98-42cb-adb4-78b01549e6db',
#    'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1673429,
#    'NewDeaths': 0,
#    'TotalDeaths': 30363,
#    'NewRecovered': 0,
#    'TotalRecovered': 1640008,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c885aa99-94f4-4314-a563-a3e7313878c1',
#    'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 50004,
#    'NewDeaths': 0,
#    'TotalDeaths': 328,
#    'NewRecovered': 0,
#    'TotalRecovered': 49187,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a73f5a5f-4ab8-4d92-9d3e-43a6f68f4d46',
#    'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 317168,
#    'NewDeaths': 0,
#    'TotalDeaths': 2549,
#    'NewRecovered': 0,
#    'TotalRecovered': 303382,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '8b6fdd33-3e8d-44d0-97d0-6ca6a49a3745',
#    'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11651,
#    'NewDeaths': 0,
#    'TotalDeaths': 156,
#    'NewRecovered': 0,
#    'TotalRecovered': 11488,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '3dc35296-c9a4-4cd7-9c97-ca2ed559ac63',
#    'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 210,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 200,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '293cf712-73b7-48a1-bb87-644e7164eee6',
#    'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 341510,
#    'NewDeaths': 0,
#    'TotalDeaths': 3956,
#    'NewRecovered': 0,
#    'TotalRecovered': 320755,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '9600323b-43be-420c-b1f7-3a14e9a99dff',
#    'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 486544,
#    'NewDeaths': 0,
#    'TotalDeaths': 31591,
#    'NewRecovered': 0,
#    'TotalRecovered': 443880,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1ffd88f9-f698-4518-b2fa-3ef18a17dd50',
#    'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 284215,
#    'NewDeaths': 0,
#    'TotalDeaths': 16518,
#    'NewRecovered': 0,
#    'TotalRecovered': 229712,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5f5a5579-e317-425c-99b0-29418e2784ff',
#    'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 86620,
#    'NewDeaths': 0,
#    'TotalDeaths': 2613,
#    'NewRecovered': 0,
#    'TotalRecovered': 76265,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a412df36-d14b-4097-88bc-c1241ed508f8',
#    'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8880,
#    'NewDeaths': 0,
#    'TotalDeaths': 123,
#    'NewRecovered': 0,
#    'TotalRecovered': 8637,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e8f0af1b-3312-491e-9ab2-5af0a8f002b6',
#    'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6545,
#    'NewDeaths': 0,
#    'TotalDeaths': 34,
#    'NewRecovered': 0,
#    'TotalRecovered': 6419,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '696737d4-429c-49ee-b6fd-7f7bc842f32b',
#    'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 133308,
#    'NewDeaths': 0,
#    'TotalDeaths': 1272,
#    'NewRecovered': 0,
#    'TotalRecovered': 128787,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '9fdb33ff-68f1-466c-914f-d6c983063e69',
#    'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 280024,
#    'NewDeaths': 0,
#    'TotalDeaths': 4383,
#    'NewRecovered': 0,
#    'TotalRecovered': 263425,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '174c2b3f-1dfc-4fac-912c-446bb7f965be',
#    'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 28660,
#    'NewDeaths': 0,
#    'TotalDeaths': 233,
#    'NewRecovered': 0,
#    'TotalRecovered': 7195,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'bb9e9cf8-7403-4377-bd06-7dfe3f1d42a6',
#    'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 106008,
#    'NewDeaths': 0,
#    'TotalDeaths': 984,
#    'NewRecovered': 0,
#    'TotalRecovered': 46000,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0946ae7f-5e0b-45dc-92a3-c8ebe591e8ac',
#    'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6166690,
#    'NewDeaths': 0,
#    'TotalDeaths': 112011,
#    'NewRecovered': 0,
#    'TotalRecovered': 412805,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '84f7f6fd-dce2-4958-9529-868704116946',
#    'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25384,
#    'NewDeaths': 0,
#    'TotalDeaths': 164,
#    'NewRecovered': 0,
#    'TotalRecovered': 25166,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'eac6ad99-09b1-4ca6-bfbd-a64dd85ac360',
#    'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7709,
#    'NewDeaths': 0,
#    'TotalDeaths': 212,
#    'NewRecovered': 0,
#    'TotalRecovered': 6600,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f8f15b33-28eb-4952-a5e8-5bca4b5f469e',
#    'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 416338,
#    'NewDeaths': 0,
#    'TotalDeaths': 5793,
#    'NewRecovered': 0,
#    'TotalRecovered': 381246,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c17607db-a289-4f7e-ba64-8c3eecb31910',
#    'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 2592,
#    'TotalConfirmed': 3774918,
#    'NewDeaths': 41,
#    'TotalDeaths': 91663,
#    'NewRecovered': 2730,
#    'TotalRecovered': 3652400,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '281cf409-d8b8-426c-85a8-0946b3296336',
#    'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 103019,
#    'NewDeaths': 0,
#    'TotalDeaths': 823,
#    'NewRecovered': 0,
#    'TotalRecovered': 97213,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '35a5bcfa-22d2-4f76-9b78-0d53263c0229',
#    'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 490552,
#    'NewDeaths': 0,
#    'TotalDeaths': 12923,
#    'NewRecovered': 0,
#    'TotalRecovered': 93764,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '167a1806-a7b2-4189-bf6d-13c233c14efb',
#    'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 164,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 161,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f5de0a7e-10c7-47d1-8826-7d00b7706ad1',
#    'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 365528,
#    'NewDeaths': 0,
#    'TotalDeaths': 10289,
#    'NewRecovered': 0,
#    'TotalRecovered': 319323,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '22fd1ec5-3abb-4ee1-afd9-ae5c7ad97021',
#    'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25564,
#    'NewDeaths': 0,
#    'TotalDeaths': 214,
#    'NewRecovered': 0,
#    'TotalRecovered': 24111,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f48fe911-5fc8-4391-847e-5170655b4d96',
#    'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4451,
#    'NewDeaths': 0,
#    'TotalDeaths': 75,
#    'NewRecovered': 0,
#    'TotalRecovered': 3897,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '16f4889d-30f0-4755-a928-f0c3d7f312de',
#    'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 22458,
#    'NewDeaths': 0,
#    'TotalDeaths': 535,
#    'NewRecovered': 0,
#    'TotalRecovered': 21166,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e6140430-f8be-44b8-bf1e-a6edb8ce82b2',
#    'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20077,
#    'NewDeaths': 0,
#    'TotalDeaths': 545,
#    'NewRecovered': 0,
#    'TotalRecovered': 12961,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '7a80e8a4-57ea-4098-a416-9c1c6933407f',
#    'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c625c699-d303-404d-86f4-543c6dba135f',
#    'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 297111,
#    'NewDeaths': 0,
#    'TotalDeaths': 7834,
#    'NewRecovered': 0,
#    'TotalRecovered': 100697,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c731957c-b6fe-4e7f-b1a8-52e790992218',
#    'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 809491,
#    'NewDeaths': 0,
#    'TotalDeaths': 30026,
#    'NewRecovered': 0,
#    'TotalRecovered': 748157,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5376f530-e638-49af-b1c6-155a4c89dfe5',
#    'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7801,
#    'NewDeaths': 0,
#    'TotalDeaths': 30,
#    'NewRecovered': 0,
#    'TotalRecovered': 6699,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '9c791f09-e7d6-44e8-8e5b-622b897b72be',
#    'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 41649,
#    'TotalConfirmed': 31613993,
#    'NewDeaths': 593,
#    'TotalDeaths': 423810,
#    'NewRecovered': 37291,
#    'TotalRecovered': 30781263,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0d667183-6557-41bf-9206-da1fcf008b62',
#    'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3372374,
#    'NewDeaths': 0,
#    'TotalDeaths': 92311,
#    'NewRecovered': 0,
#    'TotalRecovered': 2730720,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '81bb8ba4-b9ea-4006-bd2a-87d1392812ed',
#    'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3851162,
#    'NewDeaths': 0,
#    'TotalDeaths': 90344,
#    'NewRecovered': 0,
#    'TotalRecovered': 3348363,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '09db7178-d1a6-4ea5-853c-d281719b20ce',
#    'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1616384,
#    'NewDeaths': 0,
#    'TotalDeaths': 18595,
#    'NewRecovered': 0,
#    'TotalRecovered': 1455659,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '82dc2287-d10a-40fc-8823-a0dd27cb10da',
#    'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 299549,
#    'NewDeaths': 0,
#    'TotalDeaths': 5035,
#    'NewRecovered': 0,
#    'TotalRecovered': 23364,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f162b9dc-e767-4ff7-a774-4fbc151b55fe',
#    'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 871343,
#    'NewDeaths': 0,
#    'TotalDeaths': 6469,
#    'NewRecovered': 0,
#    'TotalRecovered': 848364,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '74a9991e-627d-4027-8965-8b21165bd963',
#    'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 6613,
#    'TotalConfirmed': 4343519,
#    'NewDeaths': 18,
#    'TotalDeaths': 128047,
#    'NewRecovered': 2117,
#    'TotalRecovered': 4132510,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '3364386e-17cf-4c6c-8e3f-f560bac85fa7',
#    'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 52684,
#    'NewDeaths': 0,
#    'TotalDeaths': 1187,
#    'NewRecovered': 0,
#    'TotalRecovered': 46966,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e41c067f-346f-4168-a485-b9ad6503c469',
#    'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 10592,
#    'TotalConfirmed': 914718,
#    'NewDeaths': 9,
#    'TotalDeaths': 15197,
#    'NewRecovered': 3715,
#    'TotalRecovered': 830931,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4dd2da35-f88c-4b94-a88f-e9c2459a11b1',
#    'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 770150,
#    'NewDeaths': 0,
#    'TotalDeaths': 10020,
#    'NewRecovered': 0,
#    'TotalRecovered': 750141,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0d94ee35-9e35-4306-aee6-9eb7da134f6c',
#    'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 633469,
#    'NewDeaths': 0,
#    'TotalDeaths': 5866,
#    'NewRecovered': 0,
#    'TotalRecovered': 527894,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'cb2110a1-e1d1-4b13-86ca-f2aa3250eb4a',
#    'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 201954,
#    'NewDeaths': 0,
#    'TotalDeaths': 3926,
#    'NewRecovered': 0,
#    'TotalRecovered': 188438,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4caa9159-7da2-4996-8adc-d0d47bb16ba7',
#    'Country': 'Kiribati',
#    'CountryCode': 'KI',
#    'Slug': 'kiribati',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '427e6642-fb66-4285-8833-f3c27ac06e03',
#    'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 198345,
#    'NewDeaths': 0,
#    'TotalDeaths': 2095,
#    'NewRecovered': 0,
#    'TotalRecovered': 174177,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '7a4f2a16-389b-44d1-b8ce-cc0919900426',
#    'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 397098,
#    'NewDeaths': 0,
#    'TotalDeaths': 2314,
#    'NewRecovered': 0,
#    'TotalRecovered': 382826,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '16517f9a-17f2-45ca-8805-bfd31e422cbc',
#    'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 161973,
#    'NewDeaths': 0,
#    'TotalDeaths': 2311,
#    'NewRecovered': 0,
#    'TotalRecovered': 142984,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c18afe23-d258-4e22-a3e8-efd991a7feb2',
#    'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5919,
#    'NewDeaths': 0,
#    'TotalDeaths': 6,
#    'NewRecovered': 0,
#    'TotalRecovered': 2774,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2d98a4f9-1993-4e64-b104-25fd03dd25ff',
#    'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 138799,
#    'NewDeaths': 0,
#    'TotalDeaths': 2556,
#    'NewRecovered': 0,
#    'TotalRecovered': 135463,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5dc1c010-84e4-4082-b542-46e7d72e58ab',
#    'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 560396,
#    'NewDeaths': 0,
#    'TotalDeaths': 7903,
#    'NewRecovered': 0,
#    'TotalRecovered': 536963,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '39b2995d-7145-46a1-ad14-f44204e383d0',
#    'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12908,
#    'NewDeaths': 0,
#    'TotalDeaths': 374,
#    'NewRecovered': 0,
#    'TotalRecovered': 6649,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '07a93582-61e7-4420-9365-60b760fdcad2',
#    'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5396,
#    'NewDeaths': 0,
#    'TotalDeaths': 148,
#    'NewRecovered': 0,
#    'TotalRecovered': 2715,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'faf3341c-09f5-4004-950b-545754d6811f',
#    'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 249114,
#    'NewDeaths': 0,
#    'TotalDeaths': 3509,
#    'NewRecovered': 0,
#    'TotalRecovered': 190978,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'd23fa58a-ebb1-4912-82fa-651e9965d830',
#    'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3085,
#    'NewDeaths': 0,
#    'TotalDeaths': 59,
#    'NewRecovered': 0,
#    'TotalRecovered': 3009,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '9aac3968-3885-4790-b396-8fc1498a63a3',
#    'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 282416,
#    'NewDeaths': 0,
#    'TotalDeaths': 4413,
#    'NewRecovered': 0,
#    'TotalRecovered': 269054,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c5f4f36d-1e29-4381-8666-c2a2f7bfdabb',
#    'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 73870,
#    'NewDeaths': 0,
#    'TotalDeaths': 822,
#    'NewRecovered': 0,
#    'TotalRecovered': 71867,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'd4b24eaa-6ed5-4f7b-aeda-35a86f8ce07c',
#    'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 156299,
#    'NewDeaths': 0,
#    'TotalDeaths': 5493,
#    'NewRecovered': 0,
#    'TotalRecovered': 150350,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'baf1d13b-7e90-405d-8e81-4b0c229dbef6',
#    'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 42652,
#    'NewDeaths': 0,
#    'TotalDeaths': 943,
#    'NewRecovered': 0,
#    'TotalRecovered': 41127,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5e625b31-5298-4e18-a53a-3f28ba6d7007',
#    'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 51809,
#    'NewDeaths': 0,
#    'TotalDeaths': 1614,
#    'NewRecovered': 0,
#    'TotalRecovered': 37693,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e80127ca-21d6-495b-ba73-7b606e8a5c85',
#    'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1095486,
#    'NewDeaths': 0,
#    'TotalDeaths': 8725,
#    'NewRecovered': 0,
#    'TotalRecovered': 902921,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2ddce45b-c3e0-44cb-8579-eb95f63ea648',
#    'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 77309,
#    'NewDeaths': 0,
#    'TotalDeaths': 221,
#    'NewRecovered': 0,
#    'TotalRecovered': 74481,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'cd6a52d4-1970-4c44-82d8-207f2ffe0e97',
#    'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 14574,
#    'NewDeaths': 0,
#    'TotalDeaths': 532,
#    'NewRecovered': 0,
#    'TotalRecovered': 13941,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2f5ce2e2-56a3-459e-b00e-cfdbc98791f0',
#    'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 34201,
#    'NewDeaths': 0,
#    'TotalDeaths': 423,
#    'NewRecovered': 0,
#    'TotalRecovered': 31410,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '71aec4ee-541e-4908-bfd5-d15bee47f565',
#    'Country': 'Marshall Islands',
#    'CountryCode': 'MH',
#    'Slug': 'marshall-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 4,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '83271eb2-bcd8-4eb3-991b-6eff7358d269',
#    'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25423,
#    'NewDeaths': 0,
#    'TotalDeaths': 558,
#    'NewRecovered': 0,
#    'TotalRecovered': 22113,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0723818a-96a2-4976-8d51-37a42acc1202',
#    'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3913,
#    'NewDeaths': 0,
#    'TotalDeaths': 19,
#    'NewRecovered': 0,
#    'TotalRecovered': 1854,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '9e520c7a-8ccd-4c4d-b7a6-7360f8c26e5f',
#    'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 19346,
#    'TotalConfirmed': 2829443,
#    'NewDeaths': 459,
#    'TotalDeaths': 240456,
#    'NewRecovered': 11632,
#    'TotalRecovered': 2204109,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ce612e7a-599f-41b3-b69c-fd557773fdec',
#    'Country': 'Micronesia, Federated States of',
#    'CountryCode': 'FM',
#    'Slug': 'micronesia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 1,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '67569d7f-630a-472c-9c9c-0cc31010baf2',
#    'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 259356,
#    'NewDeaths': 0,
#    'TotalDeaths': 6255,
#    'NewRecovered': 0,
#    'TotalRecovered': 251967,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '41c222ad-d9d7-4799-96fc-6b88608c8762',
#    'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2873,
#    'NewDeaths': 0,
#    'TotalDeaths': 33,
#    'NewRecovered': 0,
#    'TotalRecovered': 2700,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5da71f1b-3a6e-41e6-a94c-cf4bdcef2a46',
#    'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 162869,
#    'NewDeaths': 0,
#    'TotalDeaths': 809,
#    'NewRecovered': 0,
#    'TotalRecovered': 162788,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '25d8513f-6052-43c1-b755-f363f5ad9906',
#    'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 101785,
#    'NewDeaths': 0,
#    'TotalDeaths': 1629,
#    'NewRecovered': 0,
#    'TotalRecovered': 98940,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5bfadffa-2d99-4db8-b77a-ade41b0d00d2',
#    'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 615999,
#    'NewDeaths': 0,
#    'TotalDeaths': 9732,
#    'NewRecovered': 0,
#    'TotalRecovered': 557408,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '72051f4f-15a5-4a30-b9fa-663fd9364860',
#    'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 119950,
#    'NewDeaths': 0,
#    'TotalDeaths': 1407,
#    'NewRecovered': 0,
#    'TotalRecovered': 88081,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a69338aa-0dd9-431f-b2d2-d0eb2caa4d8a',
#    'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 294460,
#    'NewDeaths': 0,
#    'TotalDeaths': 8942,
#    'NewRecovered': 0,
#    'TotalRecovered': 205677,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '8ceed82c-91f1-4191-bf04-8c830ed56d03',
#    'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 118429,
#    'NewDeaths': 0,
#    'TotalDeaths': 2999,
#    'NewRecovered': 0,
#    'TotalRecovered': 94556,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2f568079-22a7-4ca0-ac76-3637619b6ecf',
#    'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 693109,
#    'NewDeaths': 0,
#    'TotalDeaths': 9834,
#    'NewRecovered': 0,
#    'TotalRecovered': 652261,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0b98660c-69b9-41bd-8e59-d41e8bcd1ff0',
#    'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 3387,
#    'TotalConfirmed': 1862586,
#    'NewDeaths': 6,
#    'TotalDeaths': 17821,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4fb0e15c-097d-4b67-a467-178fc278f7e1',
#    'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2871,
#    'NewDeaths': 0,
#    'TotalDeaths': 26,
#    'NewRecovered': 0,
#    'TotalRecovered': 2799,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'b0c64eb5-3afd-4610-8a97-eecb87d677b5',
#    'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 9470,
#    'NewDeaths': 0,
#    'TotalDeaths': 195,
#    'NewRecovered': 0,
#    'TotalRecovered': 4225,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2d982e8e-2a1d-48cc-a1b7-c8135ae67bde',
#    'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5616,
#    'NewDeaths': 0,
#    'TotalDeaths': 195,
#    'NewRecovered': 0,
#    'TotalRecovered': 5338,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'fdac209c-0d00-483c-ba0d-bdb9235e0a74',
#    'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 173411,
#    'NewDeaths': 0,
#    'TotalDeaths': 2149,
#    'NewRecovered': 0,
#    'TotalRecovered': 164978,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'cca106d1-3b83-472e-9ae5-b9257bba5e9d',
#    'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 137471,
#    'NewDeaths': 0,
#    'TotalDeaths': 799,
#    'NewRecovered': 0,
#    'TotalRecovered': 17998,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '7e9d1254-6814-47e3-b744-43c9eb9c9407',
#    'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 295857,
#    'NewDeaths': 0,
#    'TotalDeaths': 3814,
#    'NewRecovered': 0,
#    'TotalRecovered': 278195,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0efa0ffd-c6a4-4777-9ab2-73caad311131',
#    'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 4950,
#    'TotalConfirmed': 1029811,
#    'NewDeaths': 65,
#    'TotalDeaths': 23360,
#    'NewRecovered': 1321,
#    'TotalRecovered': 940164,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e7702dbe-16d6-42d9-8dcf-28f3d2346b7f',
#    'Country': 'Palau',
#    'CountryCode': 'PW',
#    'Slug': 'palau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4c483817-7293-4ee6-a2e7-53d2502c42b3',
#    'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 316603,
#    'NewDeaths': 0,
#    'TotalDeaths': 3601,
#    'NewRecovered': 0,
#    'TotalRecovered': 311772,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '148d4bd5-b803-4837-8a98-25f3e88d6bbe',
#    'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 434460,
#    'NewDeaths': 0,
#    'TotalDeaths': 6808,
#    'NewRecovered': 0,
#    'TotalRecovered': 415265,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '3aeccaed-a9f7-48ed-8290-f3bdb0eb6d32',
#    'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 17673,
#    'NewDeaths': 0,
#    'TotalDeaths': 192,
#    'NewRecovered': 0,
#    'TotalRecovered': 17274,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ca1f1419-1fe5-4b56-9f38-c13a5dd3e627',
#    'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 452085,
#    'NewDeaths': 0,
#    'TotalDeaths': 14929,
#    'NewRecovered': 0,
#    'TotalRecovered': 419028,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a40f392f-62eb-4f35-a3b8-5fc42fc71bd5',
#    'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2108595,
#    'NewDeaths': 0,
#    'TotalDeaths': 196214,
#    'NewRecovered': 0,
#    'TotalRecovered': 2075361,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4e3eab20-1cd6-4761-bee8-0c965fb29e4f',
#    'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1580824,
#    'NewDeaths': 0,
#    'TotalDeaths': 27722,
#    'NewRecovered': 0,
#    'TotalRecovered': 1491182,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a2960732-8262-4470-894d-86fa49d12bd0',
#    'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2882786,
#    'NewDeaths': 0,
#    'TotalDeaths': 75259,
#    'NewRecovered': 0,
#    'TotalRecovered': 2653608,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'faba4729-4a13-4d57-9343-75829d80bedc',
#    'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 966041,
#    'NewDeaths': 0,
#    'TotalDeaths': 17344,
#    'NewRecovered': 0,
#    'TotalRecovered': 897886,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e84d571c-41e6-4e2c-a4a0-f41d619d9578',
#    'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 226077,
#    'NewDeaths': 0,
#    'TotalDeaths': 601,
#    'NewRecovered': 0,
#    'TotalRecovered': 223591,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'daa106c0-c287-494c-a9dd-f5f0dc3c60f4',
#    'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 108273,
#    'NewDeaths': 0,
#    'TotalDeaths': 2269,
#    'NewRecovered': 0,
#    'TotalRecovered': 105641,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4302c929-ca37-4d93-bced-65c31148e673',
#    'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1083033,
#    'NewDeaths': 0,
#    'TotalDeaths': 34278,
#    'NewRecovered': 0,
#    'TotalRecovered': 1047682,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '97af19f8-6599-4485-946d-7196824424d9',
#    'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 23016,
#    'TotalConfirmed': 6161985,
#    'NewDeaths': 776,
#    'TotalDeaths': 155180,
#    'NewRecovered': 19989,
#    'TotalRecovered': 5520398,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'b539abf0-29a2-4dee-8517-e7d4cc42776d',
#    'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 69838,
#    'NewDeaths': 0,
#    'TotalDeaths': 798,
#    'NewRecovered': 0,
#    'TotalRecovered': 44823,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f7ac4b98-7242-4103-84b6-54a964ac25fc',
#    'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 589,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 542,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4d2dbf5c-de14-4486-841a-a932bd0b79f0',
#    'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5581,
#    'NewDeaths': 0,
#    'TotalDeaths': 89,
#    'NewRecovered': 0,
#    'TotalRecovered': 5368,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '154b5104-f6df-4dd8-93d7-927f6fb67e14',
#    'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2291,
#    'NewDeaths': 0,
#    'TotalDeaths': 12,
#    'NewRecovered': 0,
#    'TotalRecovered': 2229,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '983816ba-327d-4da3-b553-06226a47657f',
#    'Country': 'Samoa',
#    'CountryCode': 'WS',
#    'Slug': 'samoa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5a6dfac7-492b-4379-814b-72ca0a8c4ce0',
#    'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5130,
#    'NewDeaths': 0,
#    'TotalDeaths': 90,
#    'NewRecovered': 0,
#    'TotalRecovered': 5005,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'f88840d4-c65d-40bf-9e26-171aec0fc94d',
#    'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2446,
#    'NewDeaths': 0,
#    'TotalDeaths': 37,
#    'NewRecovered': 0,
#    'TotalRecovered': 2358,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '50568606-bf59-4417-ad7c-286261f95672',
#    'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 522108,
#    'NewDeaths': 0,
#    'TotalDeaths': 8200,
#    'NewRecovered': 0,
#    'TotalRecovered': 502528,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '6769c9cc-b63b-4b7e-ad16-413ce46d2b8c',
#    'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 61245,
#    'NewDeaths': 0,
#    'TotalDeaths': 1333,
#    'NewRecovered': 0,
#    'TotalRecovered': 46754,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0f81abba-8120-4a57-824c-a9d05e2d1fe4',
#    'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 721620,
#    'NewDeaths': 0,
#    'TotalDeaths': 7112,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '16851a6d-8939-4a2b-bccb-8bcb8fdc664e',
#    'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 18189,
#    'NewDeaths': 0,
#    'TotalDeaths': 94,
#    'NewRecovered': 0,
#    'TotalRecovered': 17538,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '21295b12-2fd5-4de8-8aaf-14e3077d92a0',
#    'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 6279,
#    'NewDeaths': 0,
#    'TotalDeaths': 120,
#    'NewRecovered': 0,
#    'TotalRecovered': 4260,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4ad8cdd5-c644-458a-b1d2-85786b10bb7b',
#    'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64861,
#    'NewDeaths': 0,
#    'TotalDeaths': 37,
#    'NewRecovered': 0,
#    'TotalRecovered': 62733,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2bf3cbbe-c3a9-4a26-9d4c-57c689d72a0e',
#    'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 392581,
#    'NewDeaths': 0,
#    'TotalDeaths': 12536,
#    'NewRecovered': 0,
#    'TotalRecovered': 255300,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'aea17ad4-c33e-4093-a6bc-39d03297132b',
#    'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 259079,
#    'NewDeaths': 0,
#    'TotalDeaths': 4428,
#    'NewRecovered': 0,
#    'TotalRecovered': 253681,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'eadaa708-c5ec-4276-8896-7f01fe619828',
#    'Country': 'Solomon Islands',
#    'CountryCode': 'SB',
#    'Slug': 'solomon-islands',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 20,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '0dcf3ab5-dce3-4426-b4df-c0c8004aa47b',
#    'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15358,
#    'NewDeaths': 0,
#    'TotalDeaths': 809,
#    'NewRecovered': 0,
#    'TotalRecovered': 7498,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'dfb1f530-9a65-483c-9b4d-29b32cd31682',
#    'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2435036,
#    'NewDeaths': 0,
#    'TotalDeaths': 71679,
#    'NewRecovered': 0,
#    'TotalRecovered': 2207960,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2b09bf99-448b-4574-8351-1b8c48167950',
#    'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 11049,
#    'NewDeaths': 0,
#    'TotalDeaths': 119,
#    'NewRecovered': 0,
#    'TotalRecovered': 10514,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ec3b7166-36c9-4295-8d7c-0141a248e889',
#    'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 24753,
#    'TotalConfirmed': 4447044,
#    'NewDeaths': 44,
#    'TotalDeaths': 81486,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'cca6707a-5d6a-482c-b019-e4f4eaae0a0e',
#    'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 306662,
#    'NewDeaths': 0,
#    'TotalDeaths': 4380,
#    'NewRecovered': 0,
#    'TotalRecovered': 275212,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a5965839-829f-457f-93b2-1e821d95492e',
#    'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 37138,
#    'NewDeaths': 0,
#    'TotalDeaths': 2776,
#    'NewRecovered': 0,
#    'TotalRecovered': 30647,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ab4b043d-0ee6-4d3f-b3f3-5be7da8220d5',
#    'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25287,
#    'NewDeaths': 0,
#    'TotalDeaths': 645,
#    'NewRecovered': 0,
#    'TotalRecovered': 21610,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '9ccc35d1-ab01-4542-9436-88dc695f7448',
#    'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25515,
#    'NewDeaths': 0,
#    'TotalDeaths': 779,
#    'NewRecovered': 0,
#    'TotalRecovered': 20703,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'a0b1c92c-ae3a-4030-827f-223f588bc655',
#    'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 626,
#    'TotalConfirmed': 1100040,
#    'NewDeaths': 0,
#    'TotalDeaths': 14656,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1231defd-6922-4297-ab65-f940bd86c99d',
#    'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 717665,
#    'NewDeaths': 0,
#    'TotalDeaths': 10905,
#    'NewRecovered': 0,
#    'TotalRecovered': 317600,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '25c4894b-eca5-4098-8b81-d13bb12e03e3',
#    'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 25954,
#    'NewDeaths': 0,
#    'TotalDeaths': 1913,
#    'NewRecovered': 0,
#    'TotalRecovered': 21980,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '10feebaf-897c-4d5f-a1a5-f6b5e91ac941',
#    'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15662,
#    'NewDeaths': 0,
#    'TotalDeaths': 787,
#    'NewRecovered': 0,
#    'TotalRecovered': 12817,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'e6ce99b2-b516-4d18-bbac-24a43006cb2a',
#    'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15004,
#    'NewDeaths': 0,
#    'TotalDeaths': 121,
#    'NewRecovered': 0,
#    'TotalRecovered': 14470,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'b2e65ee0-c072-4eca-b21f-6b32fa0e540b',
#    'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1017,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c44a4b49-6f0e-4f3c-8e08-a7657a339bd5',
#    'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 578375,
#    'NewDeaths': 0,
#    'TotalDeaths': 4679,
#    'NewRecovered': 0,
#    'TotalRecovered': 26873,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '1ba01c1f-b0f9-42ba-89fc-19c149de8869',
#    'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10744,
#    'NewDeaths': 0,
#    'TotalDeaths': 26,
#    'NewRecovered': 0,
#    'TotalRecovered': 9848,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '6bbb9695-5f39-4861-a2a3-7aed4a82489a',
#    'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 15624,
#    'NewDeaths': 0,
#    'TotalDeaths': 152,
#    'NewRecovered': 0,
#    'TotalRecovered': 14385,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '2f25492c-5414-4a14-b9ab-14cffa75b899',
#    'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 38557,
#    'NewDeaths': 0,
#    'TotalDeaths': 1070,
#    'NewRecovered': 0,
#    'TotalRecovered': 31565,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'b58f8d9b-b6ab-4e25-8736-e074fa62b078',
#    'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 586146,
#    'NewDeaths': 0,
#    'TotalDeaths': 19503,
#    'NewRecovered': 0,
#    'TotalRecovered': 505497,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '78d47d9b-4415-4f4c-83d6-e5e03a3ac522',
#    'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5704713,
#    'NewDeaths': 0,
#    'TotalDeaths': 51253,
#    'NewRecovered': 0,
#    'TotalRecovered': 5449253,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4f41f38c-9883-4b0b-823c-7fae06f1e1cc',
#    'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 93675,
#    'NewDeaths': 0,
#    'TotalDeaths': 2661,
#    'NewRecovered': 0,
#    'TotalRecovered': 81992,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '09e8c1df-526a-4df1-9b8d-46f25b2406f8',
#    'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 1510,
#    'TotalConfirmed': 2331950,
#    'NewDeaths': 32,
#    'TotalDeaths': 55521,
#    'NewRecovered': 1000,
#    'TotalRecovered': 2254803,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '83501d5d-95c2-41d7-8015-0c8df356e03f',
#    'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 679321,
#    'NewDeaths': 0,
#    'TotalDeaths': 1943,
#    'NewRecovered': 0,
#    'TotalRecovered': 656680,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ff4244ea-98bc-4973-af02-8d4d384a9a7d',
#    'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 29323,
#    'TotalConfirmed': 5857639,
#    'NewDeaths': 68,
#    'TotalDeaths': 129877,
#    'NewRecovered': 281,
#    'TotalRecovered': 20919,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'b69d8319-c83d-4f92-9827-6340e77ad9ee',
#    'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 194608,
#    'TotalConfirmed': 34945468,
#    'NewDeaths': 891,
#    'TotalDeaths': 613013,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c74d8986-e047-4b4e-9c09-e9bc0c9aa18d',
#    'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 381364,
#    'NewDeaths': 0,
#    'TotalDeaths': 5959,
#    'NewRecovered': 0,
#    'TotalRecovered': 373290,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'c58f4141-5318-408e-891d-911f7fc94677',
#    'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 128403,
#    'NewDeaths': 0,
#    'TotalDeaths': 866,
#    'NewRecovered': 0,
#    'TotalRecovered': 122368,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': 'ca38a757-1ae2-4dff-86d4-77fc8ea9eff0',
#    'Country': 'Vanuatu',
#    'CountryCode': 'VU',
#    'Slug': 'vanuatu',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 3,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '660028a7-accb-4fe7-bf1c-8c05bb59ea5c',
#    'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 304726,
#    'NewDeaths': 0,
#    'TotalDeaths': 3576,
#    'NewRecovered': 0,
#    'TotalRecovered': 288864,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '5b5c4729-a67a-4ce9-89ce-03e9035c6f12',
#    'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 141122,
#    'NewDeaths': 0,
#    'TotalDeaths': 1161,
#    'NewRecovered': 0,
#    'TotalRecovered': 35484,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '3eb6da49-22b2-412d-ab47-beef0284b482',
#    'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 7058,
#    'NewDeaths': 0,
#    'TotalDeaths': 1375,
#    'NewRecovered': 0,
#    'TotalRecovered': 4171,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '638cc404-0bcd-41ab-923f-70b5c5cbf5d5',
#    'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 195096,
#    'NewDeaths': 0,
#    'TotalDeaths': 3376,
#    'NewRecovered': 0,
#    'TotalRecovered': 186211,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}},
#   {'ID': '4677321b-6ad9-4807-b1e4-6368ba384a5c',
#    'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 107490,
#    'NewDeaths': 0,
#    'TotalDeaths': 3490,
#    'NewRecovered': 0,
#    'TotalRecovered': 74562,
#    'Date': '2021-07-31T16:59:39.33Z',
#    'Premium': {}}],
#  'Date': '2021-07-31T16:59:39.33Z'}
